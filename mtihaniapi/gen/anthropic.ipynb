# %%
import os
import sys

# Ensure correct path to project root
sys.path.insert(0, os.path.abspath(".."))

import django
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'mtihaniapi.settings')
django.setup()

# %%
import json
import asyncio
from typing import Any, Dict, List, Union
from operator import itemgetter

# Django/project imports
from gen.curriculum import get_cbc_grouped_questions
from gen.constants import *
from gen.utils import CREATE_EXAM_LLM_PROMPT, get_db_question_objects

from anthropic import Client

# %%
# Initialize the client
client = Client(api_key=os.getenv("ANTHROPIC_API_KEY"))

CLAUDE_SONNET_4 = "claude-sonnet-4-20250514"
CLAUDE_OPUS_4 = "claude-opus-4-20250514"

# %%
def safe_parse_llm_output(raw):
    # If it's already a list, just return it
    if isinstance(raw, list):
        return raw
    # If it's a string, try to parse as JSON
    if isinstance(raw, str):
        try:
            cleaned = raw.strip()
            # Sometimes LLMs wrap outputs in ``` or ```json code fences
            if cleaned.startswith("```"):
                cleaned = cleaned.lstrip("`").replace("json", "", 1).strip()
            return json.loads(cleaned)
        except Exception:
            print("Warning: Could not parse LLM output as JSON.")
            return []
    # If it's something else, return empty list
    return []

# %%
def generate_claude_sub_strand_questions(
    sub_strand_data: Dict[str, Any],
    llm: str,
) -> str:
    prompt_template = CREATE_EXAM_LLM_PROMPT
    formatted_prompt = prompt_template.format(
        strand=sub_strand_data["strand"],
        sub_strand=sub_strand_data["sub_strand"],
        learning_outcomes=sub_strand_data["learning_outcomes"],
        skills_to_assess=sub_strand_data["skills_to_assess"],
        skills_to_test=sub_strand_data["skills_to_test"],
        question_count=sub_strand_data["question_count"],
        sample_questions=sub_strand_data["sample_questions"],
    )

    response = client.messages.create(
        model=llm,
        max_tokens=10240,
        temperature=0.1,
        messages=[
            {"role": "user", "content": formatted_prompt}
        ]
    )
    # This works for non-streaming Claude calls:
    return "".join(block.text for block in response.content)

# %%
from asgiref.sync import sync_to_async

@sync_to_async
def get_reference_for_sub_strand(sub_strand: str) -> str:
    from rag.models import SubStrandReference
    try:
        ref = SubStrandReference.objects.get(sub_strand=sub_strand)
        return ref.reference_text or ""
    except SubStrandReference.DoesNotExist:
        return ""

# %%
async def generate_llm_question_list(
    grouped_question_data: List[Dict[str, Any]],
    llm: Any,
    output_file: str = QUESTION_LIST_OUTPUT_FILE,
) -> Union[List[Dict[str, Any]], Dict[str, Any]]:
    all_question_list = []

    for group in grouped_question_data:
        strand = group["strand"]
        sub_strand = group["sub_strand"]
        learning_outcomes = "\n- " + "\n- ".join(group["learning_outcomes"])
        skills_to_assess = "\n- " + "\n- ".join(group["skills_to_assess"])
        sample_questions = await get_reference_for_sub_strand(sub_strand)

        # Step 1: Flatten all skills with their associated breakdown number
        numbered_skills = []
        for entry in group["skills_to_test"]:
            number = entry["number"]
            for skill in entry["skills_to_test"]:
                numbered_skills.append({"number": number, "skill": skill})

        # Step 2: Build a flat list of just the skills (in order)
        skills_only = [entry["skill"] for entry in numbered_skills]

        # Step 3: Generate all questions in one LLM call
        
        
        sub_strand_data = {
            "question_count": len(skills_only),
            "strand": strand,
            "sub_strand": sub_strand,
            "learning_outcomes": learning_outcomes,
            "skills_to_assess": skills_to_assess,
            "skills_to_test": skills_only,
            "sample_questions": sample_questions,
        }
       
        print(f"\n{sub_strand} =========")

        parsed_output = generate_claude_sub_strand_questions(
            sub_strand_data=sub_strand_data,
            llm=llm,
        )

        parsed_output = safe_parse_llm_output(parsed_output)

        if not parsed_output:
            print(f"Skipping sub-strand: {sub_strand} due to un-parse-able output")
            continue

        tagged_responses = []
        for idx, qa in enumerate(parsed_output):
            # Prevent index overflow if LLM returns fewer/more questions
            if idx >= len(numbered_skills):
                break
            question_item = {}
            question_item["number"] = numbered_skills[idx]["number"]
            question_item["grade"] = group["grade"]
            question_item["strand"] = group["strand"]
            question_item["sub_strand"] = group["sub_strand"]
            question_item["bloom_skill"] = numbered_skills[idx]["skill"]
            question_item["description"] = qa["question"]
            question_item["expected_answer"] = qa["expected_answer"]
            tagged_responses.append(question_item)
        all_question_list.extend(tagged_responses)

    all_question_list = sorted(all_question_list, key=itemgetter("number"))

    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(all_question_list, f, ensure_ascii=False, indent=4)
    print(
        f"\n✅ Question list written to {output_file}. Total: {len(all_question_list)}")

    return all_question_list

# %%
grouped_questions = get_cbc_grouped_questions(
    strand_ids=[2,4,1,6,3,8,9], 
    question_count=10,
    bloom_skill_count=2,
)

# %%
selected_model = CLAUDE_SONNET_4
all_question_list = await generate_llm_question_list(
    grouped_question_data=grouped_questions,
    llm=selected_model,
)

print(all_question_list)

# If there was a generation error
if not isinstance(all_question_list, list):
    print(all_question_list)
# Out:
# Acids, Bases and Indicators =========
#
#  Q: Ethan is researching on properties of different substances. He has observed that some acidic and basic substances are very useful. Why are some bases and acids important?
# A: Acids and bases are important because they are used in various applications such as cleaning, food preservation, and manufacturing processes. They also play crucial roles in biological systems and chemical reactions.
#
# Q: Test and classify the following specimens provided into acids, neutral or bases: a) solution A b) Solution B c) Solution C
# A: Use an acid-base indicator to test each solution. If the indicator shows a red or pink color, the solution is acidic. If it shows blue or green, the solution is basic. If there is no color change, the solution is neutral.
#
# Q: Test and classify the following specimens provided into acids, neutral or bases: Specimen a) solution A b) Solution B c) Solution C
# A: Use an acid-base indicator to test each solution. Solution A, B, and C can be classified based on the color change: if it turns red, it's an acid; if it turns blue, it's a base; if there's no change, it's neutral.
#
# Human Excretory System =========
#
#  Q: Julia was asked to describe the role of the excretory system to class. What did she respond?
# A: The excretory system removes waste products from the body, regulates water and salt balance, and maintains homeostasis.
#
# Introduction to Integrated Science =========
#
#  Q: What is the scientific method?
# A: The scientific method is a systematic approach to research and experimentation used to explore observations and answer questions.
#
# Q: List the steps involved in conducting a scientific investigation.
# A: 1. Ask a question 2. Do background research 3. Construct a hypothesis 4. Test the hypothesis by conducting an experiment 5. Analyze the data and draw a conclusion 6. Communicate the results
#
# Magnetism =========
#
#  Q: Joy is curious about why her refrigerator door always stays shut without a latch and why her toy car moves on its own track. Using your knowledge of magnetism, explain how magnets might be responsible for both these phenomena.
# A: Magnets are used in refrigerator doors to create a magnetic seal that keeps the door closed. In toy cars, magnets can be used to create magnetic tracks that guide the car along a specific path.
#
# Q: Using your knowledge of magnetism, explain how magnets might be responsible for both these phenomena: why Joy's refrigerator door always stays shut without a latch and why her toy car moves on its own track.
# A: Magnets are used in refrigerator doors to create a magnetic seal that keeps the door closed. In the toy car, magnets can be used to create a magnetic track that guides the car along a specific path.
#
# Metals and Alloys =========
#
#  Q: What are the physical properties of metals?
# A: The physical properties of metals include lustre, malleability, ductility, conductivity, and high melting and boiling points.
#
# Q: What is the composition of common alloys such as brass, bronze, and steel?
# A: Brass is composed of copper and zinc, bronze is composed of copper and tin, and steel is composed of iron and carbon.
#
# Q: What are the uses of metals and alloys in day-to-day life?
# A: Metals and alloys are used in construction, transportation, electrical wiring, household appliances, and tools due to their strength, conductivity, and durability.
#
# Q: What are the causes, effects, and prevention methods of rusting?
# A: Rusting is caused by the reaction of iron with oxygen and moisture. It leads to the deterioration of metal structures. Prevention methods include painting, galvanizing, and using rust-resistant alloys.
#
# Q: Asili noticed their house had items made from different metals. What are the physical properties of these metals?
# A: The physical properties of metals include lustre, malleability, ductility, conductivity, and high melting and boiling points.
#
# Movement of Materials In and Out of the Cell =========
#
#  Q: What happens to the water movement in each cell when observing two different cells under a microscope: Cell A in a solution with a high concentration of sugar and Cell B in a solution with a low concentration of sugar?
# A: Water will move out of Cell A and into Cell B due to osmosis.
#
# Q: How does the observation of two different cells under a microscope demonstrate the process of osmosis?
# A: The movement of water from a region of low solute concentration to high solute concentration through a semi-permeable membrane demonstrates osmosis.
#
# Q: Which of the following best describes osmosis?
# A: Movement of water from a region of high concentration to low concentration through a semi-permeable membrane.
#
# Q: What happens to the water movement in each cell when observing two different cells under a microscope, one in a solution with a high concentration of sugar and the other in a solution with a low concentration of sugar?
# A: Water will move out of the cell in the high sugar concentration solution and into the cell in the low sugar concentration solution.
#
# Q: How does the observation of two different cells under a microscope, one in a solution with a high concentration of sugar and the other in a solution with a low concentration of sugar, demonstrate the process of osmosis?
# A: It demonstrates osmosis as water moves across the semi-permeable membrane from an area of low solute concentration to an area of high solute concentration.
#
# Q: Your learners are observing two different cells under a microscope: Cell A is in a solution with a high concentration of sugar and Cell B is in a solution with a low concentration of sugar. After some time, you notice changes in both cells. (a) What happens to the water movement in each cell? (b) How does this demonstrate the process of osmosis?
# A: (a) In Cell A, water will move out of the cell into the solution, causing the cell to shrink. In Cell B, water will move into the cell from the solution, causing the cell to swell. (b) This demonstrates osmosis as it shows the movement of water across a semi-permeable membrane from a region of low solute concentration to a region of high solute concentration.
#
# Q: Which of the following best describes osmosis? A) Movement of water from a region of low concentration to high concentration. B) Movement of water from a region of high concentration to low concentration through a semi-permeable membrane. C) Movement of solutes from a region of high concentration to low concentration. D) Movement of gases through a semi-permeable membrane.
# A: B) Movement of water from a region of high concentration to low concentration through a semi-permeable membrane.
#
# The Cell =========
#
#  Q: Jane and Martin have been studying cells in their science class. They need to summarize what they have learnt about the structure, function and importance of plant and animal cells. How would they explain their findings to a classmate who missed the lesson?
# A: They would explain that plant and animal cells have similar structures such as the cell membrane, cytoplasm, and nucleus, but plant cells also have a cell wall and chloroplasts. The functions of these parts include protection, energy production, and storage. The importance of cells lies in their role as the basic unit of life, enabling growth, reproduction, and response to the environment.
#
# ✅ Question list written to /Users/melaniefayne/Desktop/mtihani/mtihani_api/mtihaniapi/gen/output/question_list.json. Total: 20
# [{'number': 1, 'grade': 7, 'strand': 'Scientific Investigation', 'sub_strand': 'Introduction to Integrated Science', 'bloom_skill': 'Remembering', 'description': 'List three main branches that make up Integrated Science as a field of study.', 'expected_answer': 'Biology, Chemistry, and Physics'}, {'number': 1, 'grade': 7, 'strand': 'Scientific Investigation', 'sub_strand': 'Introduction to Integrated Science', 'bloom_skill': 'Understanding', 'description': 'Explain why understanding science is important for a student like Mary who wants to become a farmer in rural Kenya.', 'expected_answer': 'Science helps Mary understand soil composition, plant nutrition, pest control methods, weather patterns, and modern farming techniques that can improve crop yields and sustainable farming practices.'}, {'number': 2, 'grade': 7, 'strand': 'Mixtures, Elements and Compounds', 'sub_strand': 'Acids, Bases and Indicators', 'bloom_skill': 'Applying', 'description': 'Amina is helping her mother clean their kitchen and notices that lemon juice removes stains from the cutting board while baking soda helps clean greasy surfaces. Using your knowledge of acids and bases, explain why these two substances are effective for different types of cleaning tasks.', 'expected_answer': 'Lemon juice contains citric acid which can break down mineral deposits and organic stains through its acidic properties, while baking soda is a base that neutralizes acids and helps dissolve grease and oils, making each substance effective for specific cleaning applications based on their chemical nature.'}, {'number': 2, 'grade': 7, 'strand': 'Mixtures, Elements and Compounds', 'sub_strand': 'Acids, Bases and Indicators', 'bloom_skill': 'Analysing', 'description': 'During a school science fair, Kipchoge prepared red cabbage indicator and tested three unknown solutions - one turned the indicator bright red, another turned it green, and the third showed no color change. Analyze these results and determine what type of substance each solution represents and justify your reasoning.', 'expected_answer': 'The solution that turned the indicator bright red is a strong acid because acids cause plant indicators to show red colors, the solution that turned it green is a base since bases cause indicators to show blue-green colors, and the solution with no color change is neutral because neutral substances do not affect indicator colors.'}, {'number': 3, 'grade': 7, 'strand': 'Living Things and Their Environment', 'sub_strand': 'Human Excretory System', 'bloom_skill': 'Evaluating', 'description': "Kamau's doctor advised him to drink 8 glasses of water daily and avoid excessive salt intake to maintain healthy kidneys, while his friend Wanjiku was told to use sunscreen and moisturize her skin regularly. Evaluate which advice is more important for overall excretory system health and justify your reasoning.", 'expected_answer': 'Both advice are equally important because the kidneys and skin work together as parts of the excretory system - kidneys filter blood and regulate water balance while skin eliminates waste through sweat, so maintaining both kidney and skin health is essential for proper waste removal and body homeostasis.'}, {'number': 3, 'grade': 7, 'strand': 'Living Things and Their Environment', 'sub_strand': 'Human Excretory System', 'bloom_skill': 'Creating', 'description': 'Grace noticed that students in her school often skip drinking water during break time and spend long hours in the sun without protection. Create a simple daily health log format that students could use to track activities that promote both kidney and skin health throughout a school day.', 'expected_answer': 'A daily log should include columns for: Time, Water intake (glasses), Sun protection used (hat/sunscreen), Physical activity, Skin care routine (washing/moisturizing), and Notes section - with entries tracked from morning to evening to monitor kidney and skin health activities.'}, {'number': 4, 'grade': 7, ' ...

# %%
exam_questions = get_db_question_objects(
    all_question_list=all_question_list,
)

# %%
OUTPUT_FILE = os.path.join(
    BASE_DIR, "output/model_comparisons", f"{selected_model}_EXAM.txt")

def export_exam_questions_to_txt(exam_questions, output_file=OUTPUT_FILE):
    with open(output_file, "w", encoding="utf-8") as f:
        for idx, q in enumerate(exam_questions, start=1):
            f.write(f"\nQuestion {idx}\n")
            f.write("-" * 20 + "\n")
            f.write(f"Grade: {q.get('grade', '')}\n")
            f.write(f"Strand: {q.get('strand', '')}\n")
            f.write(f"Sub Strand: {q.get('sub_strand', '')}\n\n")
            
            # Handle single or multiple bloom skills per question
            bloom_skills = q.get("bloom_skills", [])
            questions = q.get("questions", [])
            answers = q.get("expected_answers", [])
            
            # If your structure is per-skill, per-QA:
            for b_idx, (bloom, ques, ans) in enumerate(zip(bloom_skills, questions, answers), start=1):
                f.write(f"Bloom Skill {b_idx}: {bloom}\n")
                f.write(f"      Q: {ques}\n")
                f.write(f"      A: {ans}\n\n")
            
            # If your structure is single-skill per question, you can do:
            # f.write(f"Bloom Skill 1: {q.get('bloom_skill', '')}\n")
            # f.write(f"      Q: {q.get('description', '')}\n")
            # f.write(f"      A: {q.get('expected_answer', '')}\n\n")
                
        print(f"✅ Exam questions exported to {output_file}")

# Usage:
# exam_questions = [...]  # your processed list of dicts
export_exam_questions_to_txt(exam_questions)
# Out:
# ✅ Exam questions exported to /Users/melaniefayne/Desktop/mtihani/mtihani_api/mtihaniapi/gen/output/model_comparisons/claude-sonnet-4-20250514_EXAM.txt
